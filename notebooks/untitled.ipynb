# %%
import sqlite3
import pandas as pd

con=sqlite3.connect(r"C:\Users\muham\OneDrive\Desktop\ipl\data\raw\ipl.db")
def q(sql):
    return pd.read_sql_recovery(sql,con)
